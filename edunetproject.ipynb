# %% [markdown]
# <a href="https://colab.research.google.com/github/vasavipinnam/EDUNET/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

image_path = '/content/Screenshot 2025-06-11 083959.png'
image = cv2.imread(image_path)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

image = cv2.resize(image, (200, 200))

pixels = image.reshape(-1, 3)

k = 5
kmeans = KMeans(n_clusters=k)
kmeans.fit(pixels)

colors = kmeans.cluster_centers_.astype(int)

def plot_colors(colors):
    bar = np.zeros((50, 300, 3), dtype='uint8')
    width = 300 // k
    for i, color in enumerate(colors):
        bar[:, i*width:(i+1)*width] = color
    return bar

color_bar = plot_colors(colors)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.title('Original Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(color_bar)
plt.title('Dominant Colors')
plt.axis('off')

plt.tight_layout()
plt.show()
